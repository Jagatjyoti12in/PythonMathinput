# %%
import math
x=round(math.sqrt(25))
x
# Out:
# 5

# %% [markdown]
# # 17th March 2026

# %%
math.floor(3.8)
# Out:
# 3

# %%
math.ceil(3.8)
# Out:
# 4

# %%
pow(3,2)
# Out:
# 9

# %%
math.pi
# Out:
# 3.141592653589793

# %% [markdown]
# pi = 3.17
# pi

# %%
pi = 3.17
pi
# Out:
# 3.17

# %% [markdown]
# help()

# %% [raw]
# help()

# %%
q

# %%
m.sqrt(49)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 m.sqrt(49)
#
# NameError: name 'm' is not defined

# %%
math.sqrt(49)
# Out:
# 7.0

# %%
import math as m
m.sqrt(49)
# Out:
# 7.0

# %%
import nareshit as nit
import indianinstituteoftechnology as iit

# %%
from math import sqrt,pow
print(pow(2,3))
print(sqrt(25))
# Out:
# 8.0
# 5.0

# %%
from math import*

# %%
from math import sqrt, pow

print(pow(2, 3))
print(sqrt(25))
# Out:
# 8.0
# 5.0

# %%
print(math.e)
# Out:
# 2.718281828459045

# %% [markdown]
# #Input() Functions

# %%
input()
# Out:
#  hello
# 'hello'

# %%
input
input()
# Out:
#  hello
# 'hello'

# %%
x = input()
y = input()
z = x+y
print(z)
# Out:
#  12
#  13
# 1213

# %%
print(type(x))
# Out:
# <class 'str'>

# %%
x = int(input())
y = int(input())
z = x+y
print(z)
# Out:
#  12
#  13
# 25

# %%
x = int(input('Enter first number'))
y = int(input('Enter second number'))
z = x+y
print('Sum =' ,z)
# Out:
# Enter first number 12
# Enter second number 13
# Sum = 25

# %%
x = int(input('Enter User name'))
y = int(input('Enter Password:'))
z = x+y
print(z)
# Out:
# Enter User name jj
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 x = int(input('Enter User name'))
#       2 y = int(input('Enter Password:'))
#       3 z = x+y
#
# ValueError: invalid literal for int() with base 10: 'jj'

# %%
st = input('enter a sting')
print(st)
# Out:
# enter a sting jj
# jj

# %%
st = input('enter a sting')[0]
print(st)
# Out:
# enter a sting hello
# h

# %%
st = input('enter a sting')[0:2]
print(st)
# Out:
# enter a sting Hello
# He

# %%
st = input('enter a Addhar')[10:12]
print(st)
